# %%
from skimage import *
import numpy as np
from matplotlib import pyplot as plt
my_image = io.imread("images/a.jpg")
plt.imshow(my_image)
print(my_image.min(), my_image.max())
# Out:
# 0 255

# %%
random_image = np.random.random([500,500])
plt.imshow(random_image)
print(random_image.min(), random_image.max())
# Out:
# 6.657657021680308e-06 0.9999988985727765

# %%
my_float_image = img_as_float(my_image)
print(my_float_image.min(), my_float_image.max())
plt.imshow(my_float_image)
# Out:
# 0.0 1.0

# %%
dark_image = my_image*0.5
plt.imshow(dark_image)
print(dark_image.min(), dark_image.max())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.0 127.5

# %%
my_image[10:200,10:200,:] = [255, 0,0]
plt.imshow(my_image)

# %%
my_image[10:200,10:200,:] = [255, 255,0]
plt.imshow(my_image)
