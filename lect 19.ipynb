# %%
# from scipy import misc
# import PIL
# img = misc.imread("Images/a.jpg")
# print(type(img))

# %%
img = io.imread("Images/a.jpg")

print(img.dtype)
print(img.shape)
# Out:
# uint8
# (900, 1600, 3)

# %%
img = img_as_ubyte(io.imread("Images/a.jpg",as_gray=True))
print(img.shape, img.dtype)
print(img[10:15,20:25])
mean_grey = img.mean()
max_value = img.max()
min_value = img.min()

print("Min, Max, and Mean are:", min_value,max_value,mean_grey)
# Out:
# (900, 1600) uint8
# [[2 3 3 2 1]
#  [2 2 3 2 1]
#  [2 2 3 2 1]
#  [1 3 3 2 1]
#  [1 3 3 2 1]]
# Min, Max, and Mean are: 0 243 32.81588333333333

# %%
flippedLR = np.fliplr(img)
flippedUD = np.flipud(img)
plt.subplot(3,3,1)
plt.imshow(img)
plt.subplot(3,3,2)
plt.imshow(flippedLR)
plt.subplot(3,3,3)
plt.imshow(flippedUD)
plt.subplot(3,3,4)
plt.imshow(img,cmap="Greys")
plt.subplot(3,3,5)
plt.imshow(img,cmap="Blues")
plt.subplot(3,3,6)
plt.imshow(img,cmap="hsv")
plt.subplot(3,3,7)
plt.imshow(img,cmap="hsv")

# %%
rotated = ndimage.rotate(img,45)
plt.imshow(rotated)

# %%
rotated = ndimage.rotate(img,45,reshape=False)
plt.imshow(rotated)

# %%
uniform_filtered = ndimage.uniform_filter(img, size=15)
plt.imshow(uniform_filtered)

# %%
gaussian_filtered = ndimage.gaussian_filter(img, sigma=11)
plt.imshow(gaussian_filtered)

# %%
median_filtered = ndimage.median_filter(img, 3)
plt.imshow(median_filtered)

# %%
sobel_img = ndimage.sobel(img)
plt.imshow(sobel_img)

# %%
sobel_img = ndimage.sobel(img,axis=0)
plt.imshow(sobel_img)
